# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/lena.png` and show it:

# %%
img = plt.imread('data/lena.png')
plt.imshow(img, 'gray')

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical $3 \times 3$ Prewitt filters:

# %%
def prewitt_h(img, size):
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2
    x = numpy.array([[1, 0, -1],[1, 0, -1],[1, 0, -1]], numpy.int32)
    for p in numpy.ndindex(img.shape[1]-2*n, img.shape[0]-2*n):
        neighborhood_sum = 0
        for q in numpy.ndindex(size, size):
            pos = tuple(map(lambda x, y: x + y, p, q))
            neighborhood_sum += img[pos] * x[q]
            result[p[0]+n, p[1]+n] = neighborhood_sum/(size*2)
    return result
    
def prewitt_v(img, size):
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2
    x = numpy.array([[-1, -1, -1],[0, 0, 0],[1, 1, 1]], numpy.int32)
    for p in numpy.ndindex(img.shape[1]-2*n, img.shape[0]-2*n):
        neighborhood_sum = 0
        for q in numpy.ndindex(size, size):
            pos = tuple(map(lambda x, y: x + y, p, q))
            neighborhood_sum += img[pos] * x[q]
            result[p[0]+n, p[1]+n] = neighborhood_sum/(size*2)
    return result

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %%
plt.imshow(prewitt_h(img.copy(), 3), 'gray')
plt.colorbar()

# %%
plt.imshow(prewitt_v(img.copy(), 3), 'gray')
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/lena_prewitt_h.tiff` and `data/lena_prewitt_v.tiff`:

# %%
import skimage.io
lena_correct_h = skimage.io.imread('data/lena_prewitt_h.tiff')
lena_correct_v = skimage.io.imread('data/lena_prewitt_v.tiff')

assert numpy.allclose(prewitt_h(img.copy(), 3), lena_correct_h, atol=1/255)
assert numpy.allclose(prewitt_v(img.copy(), 3), lena_correct_v, atol=1/255)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[26], line 5
#       2 lena_correct_h = skimage.io.imread('data/lena_prewitt_h.tiff')
#       3 lena_correct_v = skimage.io.imread('data/lena_prewitt_v.tiff')
# ----> 5 assert numpy.allclose(prewitt_h(img.copy(), 3), lena_correct_h, atol=1/255)
#       6 assert numpy.allclose(prewitt_v(img.copy(), 3), lena_correct_v, atol=1/255)
#
# AssertionError:

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/lena_prewitt_gradmag.tiff`:

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical $3 \times 3$ Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/lena_sobel_h.tiff` and `data/lena_sobel_v.tiff`:
